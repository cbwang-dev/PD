# %% [markdown]
# # Overview for Baseline CNN
#
# - baseline model, I will introduce other models based on the increment  (modification) of this model.
# - really simple structure, only one convolutional layer, 1 `size=(16,64)` conv kernel
# - trained for a really small epochs (15) then fulfilled early stopping criterions.

# %% [markdown]
# # Preparation (RUN ALL)

# %% [markdown]
# ## Hyperparameters (tunable)
#
# Some of the tunable parameters are hidden in side the code blocks, eg.
#
# - [change learning rate scheduler](https://colab.research.google.com/drive/1ObiicTOnIh3rf9kPfQ6inWMeSHe4dDUB#scrollTo=q33NkT-xTORX&line=30&uniqifier=1)
# - after pre-trained and fine tuned, the necessary parameters should be updated in the [last part](#Test-for-given-unknown-test-set)

# %%
window_len_sec = 10; # 25,10,5,2,1 sec can be evaluated

normalization=True;
# parameters regarding to model
epochs = 200; # larger than necessary
filters = 1
kernel_size = 16
batch_size = 128
experiment_index = 1

# %% [markdown]
# ## Hyperparameters (no tune)

# %%
checkpoint_save_dir  = '/content/drive/MyDrive/PD/checkpoints/baseline/'
SNR_100_mat_path='/content/drive/MyDrive/PD/dataset_CNN_SNR_100.mat'
SNR_4_mat_path='/content/drive/MyDrive/PD/dataset_CNN_SNR_4.mat'
model_save_dir='/content/drive/MyDrive/PD/model/baseline/'
test_subj_1_37_mat_path='/content/drive/MyDrive/PD/preprocessed_CNN_test_sub_1_37'
test_subj_40_41_42_mat_path='/content/drive/MyDrive/PD/preprocessed_CNN_test_sub_40_41_42'
test_subjs = [test_subj_1_37_mat_path, test_subj_40_41_42_mat_path]
downsample_freq_CNN = 70
window_len_samples = window_len_sec * downsample_freq_CNN # 700

# %% [markdown]
# ## Libraries

# %%
# imports and directories
from scipy.io import loadmat
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, Activation
from keras import regularizers
import tensorflow as tf 
from tensorflow.python.ops.linalg_ops import norm
import h5py
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount("/content/drive")
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential, load_model
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Callbacks
#
# - learning rate scheduler set to `(0, 0.2), (20, 0.1), (40, 0.05), 80, 0.02)`
# - early stopping monitors validation loss, if no consecutive improvements after 10 epochs, then the training process is stopped.
# - checkpoint: nothing tunable.

# %% [markdown]
# #### Learning Rate Scheduler

# %%
class CustomLearningRateScheduler(keras.callbacks.Callback):

    def __init__(self, schedule):
        super(CustomLearningRateScheduler, self).__init__()
        self.schedule = schedule

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, "lr"):
            raise ValueError('Optimizer must have a "lr" attribute.')
        # Get the current learning rate from model's optimizer.
        lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        # Call schedule function to get the scheduled learning rate.
        scheduled_lr = self.schedule(epoch, lr)
        # Set the value back to the optimizer before this epoch starts
        tf.keras.backend.set_value(self.model.optimizer.lr, scheduled_lr)
        print("Learning rate is %6.4f." % (scheduled_lr))

LR_SCHEDULE = [
    # (epoch to start, learning rate) tuples
    (0, 0.2),
    (20, 0.1),
    (40, 0.05),
    (80, 0.02),
] 
# Used in pretraining, updated in subject-specific retraining. The learning rate
# is divided by 10 during subject-specific retraining. 

def lr_schedule(epoch, lr):
    if epoch < LR_SCHEDULE[0][0] or epoch > LR_SCHEDULE[-1][0]:
        return lr
    for i in range(len(LR_SCHEDULE)):
        if epoch == LR_SCHEDULE[i][0]:
          return LR_SCHEDULE[i][1]
    return lr # if loss stagnate, return lr * 0.1

# %% [markdown]
# ### Early Stopping

# %%
early_stopping = EarlyStopping(monitor="val_acc",
                               min_delta=0, # no loss reduction
                               patience=10, # 10 non-consecutive epochs
                               verbose=1,
                               mode="max",
                               restore_best_weights=True,
                               )

# %% [markdown]
# ### Model Checkpoint

# %%
checkpoint_pre_train = ModelCheckpoint(filepath = checkpoint_save_dir + 'exp_' + str(experiment_index) +'_pretrained_epoch_{epoch:02d}_val_acc{val_acc:.2f}.h5',
                             monitor='val_acc', 
                             verbose=2, 
                             save_best_only=True, 
                             mode='max')
checkpoint_fine_tune = ModelCheckpoint(filepath = checkpoint_save_dir + 'exp_' + str(experiment_index) +'_finetuned_epoch_{epoch:02d}_val_acc{val_acc:.2f}.h5',
                             monitor='val_acc', 
                             verbose=2, 
                             save_best_only=True, 
                             mode='max')

# %% [markdown]
# ### Finale: Callback List

# %%
callbacks_list_pre_train = [CustomLearningRateScheduler(lr_schedule), checkpoint_pre_train, early_stopping]
callbacks_list_fine_tune = [CustomLearningRateScheduler(lr_schedule), checkpoint_fine_tune, early_stopping]

# %% [markdown]
# ## Model (baseline CNN)

# %%
def baseline_model(window_len_samples):
  eeg  = tf.keras.layers.Input(shape=[window_len_samples, 64])
  env1 = tf.keras.layers.Input(shape=[window_len_samples, 1])
  env2 = tf.keras.layers.Input(shape=[window_len_samples, 1])

  # add more layers
  eeg_conv = tf.keras.layers.Conv1D(filters, kernel_size=kernel_size)(eeg)
  cos1 = tf.keras.layers.Dot(1,normalize= True)([eeg_conv , env1[:,:-(kernel_size-1),:]])
  cos2 = tf.keras.layers.Dot(1,normalize= True)([eeg_conv , env2[:,:-(kernel_size-1),:]])

  # Classification
  out1 = tf.keras.layers.Dense(1, activation="sigmoid")(tf.keras.layers.Flatten()(tf.keras.layers.Concatenate()([cos1, cos2])))

  # 1 output per batch
  out = tf.keras.layers.Reshape([1])(out1)
  model = tf.keras.Model(inputs=[eeg, env1, env2], outputs=[out])
  model.summary()
  
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=0.2),
      metrics=["acc"],
      loss=["binary_crossentropy"])
  return model

# To check the model summary:
model = baseline_model(window_len_samples)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 700, 64)]    0           []
#
#  input_2 (InputLayer)           [(None, 700, 1)]     0           []
#
#  input_3 (InputLayer)           [(None, 700, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 685, 1)       1025        ['input_1[0][0]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 685, 1)      0           ['input_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 685, 1)      0           ['input_3[0][0]']
#  icingOpLambda)
#
#  dot (Dot)                      (None, 1, 1)         0           ['conv1d[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  dot_1 (Dot)                    (None, 1, 1)         0           ['conv1d[0][0]',
#                                                                   'tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  concatenate (Concatenate)      (None, 1, 2)         0           ['dot[0][0]',
#                                                                   'dot_1[0][0]']
#
#  flatten (Flatten)              (None, 2)            0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 1)            3           ['flatten[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 1,028
# Trainable params: 1,028
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Pre Train (SNR 100)

# %% [markdown]
# ## Dataset Loading (SNR 100)
#
# Information of `dataset_CNN_SNR_100.mat`:
# - contains:
#   - `EEG_SNR_100_train_set`: 80% of the preprocessed EEG trials with SNR of 100.
#   - `env_attended_SNR_100_train_set`
#   - `env_unattended_SNR_100_train_set`
#   - `EEG_SNR_100_test_set`: 20% of the preprocessed EEG trials with SNR of 100. Randomly chosen and different from training set.
#   - `env_attended_SNR_100_test_set`
#   - `env_unattended_SNR_100_test_set`

# %%
# load dataset
mat_path = SNR_100_mat_path
print("INFO: loading dataset SNR 100", mat_path)
mat_contents = loadmat(mat_path)
EEG_test = mat_contents['EEG_SNR_100_test_set']
env_attended_test = mat_contents['env_attended_SNR_100_test_set']
env_unattended_test = mat_contents['env_unattended_SNR_100_test_set']
EEG_train = mat_contents['EEG_SNR_100_train_set']
env_attended_train = mat_contents['env_attended_SNR_100_train_set']
env_unattended_train = mat_contents['env_unattended_SNR_100_train_set']
print("size of EEG train is", EEG_train.shape)
print("size of attended env train is", env_attended_train.shape)
print("size of unattended env train is", env_unattended_train.shape)
print("size of EEG test is", EEG_test.shape)
print("size of attended env test is", env_attended_test.shape)
print("size of unattended env test is", env_unattended_test.shape)
# Out:
# INFO: loading dataset SNR 100 /content/drive/MyDrive/PD/dataset_CNN_SNR_100.mat
# size of EEG train is (692, 3500, 64)
# size of attended env train is (692, 3500)
# size of unattended env train is (692, 3500)
# size of EEG test is (172, 3500, 64)
# size of attended env test is (172, 3500)
# size of unattended env test is (172, 3500)

# %%
# arrange this to specific window length
print("INFO: resizing dataset to window length of", window_len_sec, 'seconds')
EEG_test.resize(EEG_test.shape[0]*int(EEG_test.shape[1]/window_len_samples), window_len_samples, EEG_test.shape[2])
env_attended_test.resize(env_attended_test.shape[0]*int(env_attended_test.shape[1]/window_len_samples), window_len_samples)
env_unattended_test.resize(env_unattended_test.shape[0]*int(env_unattended_test.shape[1]/window_len_samples), window_len_samples)
EEG_train.resize(EEG_train.shape[0]*int(EEG_train.shape[1]/window_len_samples), window_len_samples, EEG_train.shape[2])
env_attended_train.resize(env_attended_train.shape[0]*int(env_attended_train.shape[1]/window_len_samples), window_len_samples)
env_unattended_train.resize(env_unattended_train.shape[0]*int(env_unattended_train.shape[1]/window_len_samples), window_len_samples)
print("size of EEG train is ", EEG_train.shape)
print("size of attended env train is ", env_attended_train.shape)
print("size of unattended env train is ", env_unattended_train.shape)
print("size of EEG test is ", EEG_test.shape)
print("size of attended env test is ", env_attended_test.shape)
print("size of unattended env test is ", env_unattended_test.shape)
# Out:
# INFO: resizing dataset to window length of 10 seconds
# size of EEG train is  (3460, 700, 64)
# size of attended env train is  (3460, 700)
# size of unattended env train is  (3460, 700)
# size of EEG test is  (860, 700, 64)
# size of attended env test is  (860, 700)
# size of unattended env test is  (860, 700)

# %%
# equalize or balance the dataset
def batch_equalizer(eeg, env1, env2, labels):
    # present each of the eeg segments twice, where the envelopes, and thus the labels 
    # are swapped around. EEG presented in small segments [bs, window_length, 64]
    return np.concatenate([eeg,eeg], axis=0), np.concatenate([env1, env2], axis=0),np.concatenate([env2, env1], axis=0), np.concatenate([labels, (labels+1)%2], axis=0)
print("INFO: balancing dataset")
labels_test = np.zeros((EEG_test.shape[0],1))
EEG_test, env_attended_test, env_unattended_test, labels_test = batch_equalizer(EEG_test, env_attended_test, env_unattended_test, labels_test)
labels_train = np.zeros((EEG_train.shape[0],1))
EEG_train, env_attended_train, env_unattended_train, labels_train = batch_equalizer(EEG_train, env_attended_train, env_unattended_train, labels_train)
print("size of EEG train is ", EEG_train.shape)
print("size of attended env train is ", env_attended_train.shape)
print("size of unattended env train is ", env_unattended_train.shape)
print("size of EEG test is ", EEG_test.shape)
print("size of attended env test is ", env_attended_test.shape)
print("size of unattended env test is ", env_unattended_test.shape)
# Out:
# INFO: balancing dataset
# size of EEG train is  (6920, 700, 64)
# size of attended env train is  (6920, 700)
# size of unattended env train is  (6920, 700)
# size of EEG test is  (1720, 700, 64)
# size of attended env test is  (1720, 700)
# size of unattended env test is  (1720, 700)

# %%
# normalize the dataset. be careful not to useall the ram up!!! or it will crash!!!
# I can do a better normalization, but it requires RAM size. 
if normalization is True:
  all_EEG = np.concatenate((EEG_train, EEG_test), axis=0)
  all_env = np.concatenate((env_attended_train, env_unattended_train, env_attended_test, env_unattended_test), axis=0)
  print("INFO: before normalization")
  print("size of all_EEG: ", all_EEG.shape)
  print("size of all_env: ", all_env.shape)
  print("mean of all_EEG: ", np.mean(all_EEG), ". std of all_EEG: ", np.std(all_EEG))
  print("mean of all_env: ", np.mean(all_env), ". std of all_env: ", np.std(all_env))
  print("mean of EEG_train: ", np.mean(EEG_train), ". std of EEG_train: ", np.std(EEG_train))
  print("mean of env_attended_train: ", np.mean(env_attended_train), ". std of EEG_train: ", np.std(env_attended_train))
  print("mean of env_unattended_train: ", np.mean(env_unattended_train), ". std of EEG_train: ", np.std(env_unattended_train))
  print("mean of EEG_test: ", np.mean(EEG_test), ". std of EEG_train: ", np.std(EEG_test))
  print("mean of env_attended_test: ", np.mean(env_attended_test), ". std of EEG_train: ", np.std(env_attended_test))
  print("mean of env_unattended_test: ", np.mean(env_unattended_test), ". std of EEG_train: ", np.std(env_unattended_test))
  EEG_train = EEG_train / np.std(all_EEG)
  EEG_test = EEG_test / np.std(all_EEG)
  env_attended_train = env_attended_train / np.std(all_env)
  env_unattended_train = env_unattended_train / np.std(all_env)
  env_attended_test = env_attended_test / np.std(all_env)
  env_unattended_test = env_unattended_test / np.std(all_env)
  print("INFO: after normalization")
  print("mean of EEG_train: ", np.mean(EEG_train), ". std of EEG_train: ", np.std(EEG_train))
  print("mean of env_attended_train: ", np.mean(env_attended_train), ". std of EEG_train: ", np.std(env_attended_train))
  print("mean of env_unattended_train: ", np.mean(env_unattended_train), ". std of EEG_train: ", np.std(env_unattended_train))
  print("mean of EEG_test: ", np.mean(EEG_test), ". std of EEG_train: ", np.std(EEG_test))
  print("mean of env_attended_test: ", np.mean(env_attended_test), ". std of EEG_train: ", np.std(env_attended_test))
  print("mean of env_unattended_test: ", np.mean(env_unattended_test), ". std of EEG_train: ", np.std(env_unattended_test))
else:
  print("skipping normalization.")
# Out:
# INFO: before normalization
# size of all_EEG:  (8640, 700, 64)
# size of all_env:  (17280, 700)
# mean of all_EEG:  2.5848933175495923e-11 . std of all_EEG:  11.380040259696543
# mean of all_env:  0.0007783501517158843 . std of all_env:  0.24807946980324394
# mean of EEG_train:  -7.537633431916678e-11 . std of EEG_train:  11.375468242761354
# mean of env_attended_train:  0.0007321425867751914 . std of EEG_train:  0.24808747299800848
# mean of env_unattended_train:  0.0007321425867751913 . std of EEG_train:  0.24808747299800868
# mean of EEG_test:  4.3310407871826923e-10 . std of EEG_train:  11.398416122204138
# mean of env_attended_test:  0.0009642550060121662 . std of EEG_train:  0.24804718131299952
# mean of env_unattended_test:  0.0009642550060121663 . std of EEG_train:  0.2480471813129995
# INFO: after normalization
# mean of EEG_train:  -6.623555509002853e-12 . std of EEG_train:  0.9995982424639213
# mean of env_attended_train:  0.0029512421457360645 . std of EEG_train:  1.000032260608953
# mean of env_unattended_train:  0.0029512421457360684 . std of EEG_train:  1.0000322606089536
# mean of EEG_test:  3.80582187592561e-11 . std of EEG_train:  1.0016147449471398
# mean of env_attended_test:  0.0038868795018666127 . std of EEG_train:  0.9998698461816689
# mean of env_unattended_test:  0.0038868795018666114 . std of EEG_train:  0.9998698461816686

# %% [markdown]
# ## Train (SNR 100)

# %%
history = model.fit([EEG_train, env_attended_train, env_unattended_train], 
                    labels_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.2,
                    verbose=2,
                    shuffle=True,
                    callbacks=callbacks_list_pre_train)
filepath = model_save_dir + "exp_" + str(experiment_index) + "_final_pretrain.h5"
model.save(filepath)
# Out:
# Learning rate is 0.2000.
# Epoch 1/200
#
# Epoch 1: val_acc improved from -inf to 0.02746, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_01_val_acc0.03.h5
# 44/44 - 19s - loss: 0.6538 - acc: 0.6268 - val_loss: 1.0473 - val_acc: 0.0275 - 19s/epoch - 437ms/step
# Learning rate is 0.2000.
# Epoch 2/200
#
# Epoch 2: val_acc improved from 0.02746 to 0.30853, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_02_val_acc0.31.h5
# 44/44 - 15s - loss: 0.5858 - acc: 0.6889 - val_loss: 0.9761 - val_acc: 0.3085 - 15s/epoch - 347ms/step
# Learning rate is 0.2000.
# Epoch 3/200
#
# Epoch 3: val_acc improved from 0.30853 to 0.46532, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_03_val_acc0.47.h5
# 44/44 - 15s - loss: 0.5014 - acc: 0.7581 - val_loss: 0.8801 - val_acc: 0.4653 - 15s/epoch - 346ms/step
# Learning rate is 0.2000.
# Epoch 4/200
#
# Epoch 4: val_acc improved from 0.46532 to 0.46821, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_04_val_acc0.47.h5
# 44/44 - 15s - loss: 0.4492 - acc: 0.7906 - val_loss: 0.9363 - val_acc: 0.4682 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 5/200
#
# Epoch 5: val_acc improved from 0.46821 to 0.55058, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_05_val_acc0.55.h5
# 44/44 - 15s - loss: 0.4122 - acc: 0.8096 - val_loss: 0.8155 - val_acc: 0.5506 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 6/200
#
# Epoch 6: val_acc did not improve from 0.55058
# 44/44 - 16s - loss: 0.3877 - acc: 0.8257 - val_loss: 0.8825 - val_acc: 0.5455 - 16s/epoch - 352ms/step
# Learning rate is 0.2000.
# Epoch 7/200
#
# Epoch 7: val_acc improved from 0.55058 to 0.63584, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_07_val_acc0.64.h5
# 44/44 - 15s - loss: 0.3664 - acc: 0.8349 - val_loss: 0.7019 - val_acc: 0.6358 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 8/200
#
# Epoch 8: val_acc did not improve from 0.63584
# 44/44 - 15s - loss: 0.3521 - acc: 0.8448 - val_loss: 0.8982 - val_acc: 0.5477 - 15s/epoch - 348ms/step
# Learning rate is 0.2000.
# Epoch 9/200
#
# Epoch 9: val_acc did not improve from 0.63584
# 44/44 - 15s - loss: 0.3519 - acc: 0.8423 - val_loss: 0.7751 - val_acc: 0.6055 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 10/200
#
# Epoch 10: val_acc did not improve from 0.63584
# 44/44 - 20s - loss: 0.3349 - acc: 0.8506 - val_loss: 0.8706 - val_acc: 0.5744 - 20s/epoch - 466ms/step
# Learning rate is 0.2000.
# Epoch 11/200
#
# Epoch 11: val_acc did not improve from 0.63584
# 44/44 - 17s - loss: 0.3286 - acc: 0.8542 - val_loss: 0.8507 - val_acc: 0.5896 - 17s/epoch - 386ms/step
# Learning rate is 0.2000.
# Epoch 12/200
#
# Epoch 12: val_acc did not improve from 0.63584
# 44/44 - 15s - loss: 0.3234 - acc: 0.8562 - val_loss: 0.8629 - val_acc: 0.5766 - 15s/epoch - 347ms/step
# Learning rate is 0.2000.
# Epoch 13/200
#
# Epoch 13: val_acc did not improve from 0.63584
# 44/44 - 15s - loss: 0.3109 - acc: 0.8651 - val_loss: 0.8375 - val_acc: 0.5947 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 14/200
#
# Epoch 14: val_acc did not improve from 0.63584
# 44/44 - 15s - loss: 0.3060 - acc: 0.8654 - val_loss: 0.8595 - val_acc: 0.5910 - 15s/epoch - 348ms/step
# Learning rate is 0.2000.
# Epoch 15/200
#
# Epoch 15: val_acc improved from 0.63584 to 0.64884, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_15_val_acc0.65.h5
# 44/44 - 15s - loss: 0.3068 - acc: 0.8640 - val_loss: 0.7316 - val_acc: 0.6488 - 15s/epoch - 347ms/step
# Learning rate is 0.2000.
# Epoch 16/200
#
# Epoch 16: val_acc did not improve from 0.64884
# 44/44 - 15s - loss: 0.2942 - acc: 0.8707 - val_loss: 0.8420 - val_acc: 0.5903 - 15s/epoch - 349ms/step
# Learning rate is 0.2000.
# Epoch 17/200
#
# Epoch 17: val_acc improved from 0.64884 to 0.65607, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_17_val_acc0.66.h5
# 44/44 - 15s - loss: 0.3025 - acc: 0.8681 - val_loss: 0.7234 - val_acc: 0.6561 - 15s/epoch - 352ms/step
# Learning rate is 0.2000.
# Epoch 18/200
#
# Epoch 18: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2876 - acc: 0.8745 - val_loss: 0.7676 - val_acc: 0.6387 - 15s/epoch - 350ms/step
# Learning rate is 0.2000.
# Epoch 19/200
#
# Epoch 19: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2809 - acc: 0.8801 - val_loss: 0.7437 - val_acc: 0.6409 - 15s/epoch - 347ms/step
# Learning rate is 0.2000.
# Epoch 20/200
#
# Epoch 20: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2886 - acc: 0.8736 - val_loss: 0.8959 - val_acc: 0.5853 - 15s/epoch - 349ms/step
# Learning rate is 0.1000.
# Epoch 21/200
#
# Epoch 21: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2582 - acc: 0.8867 - val_loss: 0.8005 - val_acc: 0.6272 - 15s/epoch - 346ms/step
# Learning rate is 0.1000.
# Epoch 22/200
#
# Epoch 22: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2541 - acc: 0.8936 - val_loss: 0.8117 - val_acc: 0.6243 - 15s/epoch - 348ms/step
# Learning rate is 0.1000.
# Epoch 23/200
#
# Epoch 23: val_acc did not improve from 0.65607
# 44/44 - 20s - loss: 0.2506 - acc: 0.8947 - val_loss: 0.7554 - val_acc: 0.6402 - 20s/epoch - 454ms/step
# Learning rate is 0.1000.
# Epoch 24/200
#
# Epoch 24: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2593 - acc: 0.8889 - val_loss: 0.7519 - val_acc: 0.6510 - 15s/epoch - 347ms/step
# Learning rate is 0.1000.
# Epoch 25/200
#
# Epoch 25: val_acc did not improve from 0.65607
# 44/44 - 15s - loss: 0.2488 - acc: 0.8945 - val_loss: 0.7741 - val_acc: 0.6351 - 15s/epoch - 346ms/step
# Learning rate is 0.1000.
# Epoch 26/200
#
# Epoch 26: val_acc improved from 0.65607 to 0.66040, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_26_val_acc0.66.h5
# 44/44 - 15s - loss: 0.2438 - acc: 0.8988 - val_loss: 0.7499 - val_acc: 0.6604 - 15s/epoch - 348ms/step
# Learning rate is 0.1000.
# Epoch 27/200
#
# Epoch 27: val_acc did not improve from 0.66040
# 44/44 - 15s - loss: 0.2475 - acc: 0.8952 - val_loss: 0.7507 - val_acc: 0.6438 - 15s/epoch - 347ms/step
# Learning rate is 0.1000.
# Epoch 28/200
#
# Epoch 28: val_acc did not improve from 0.66040
# 44/44 - 15s - loss: 0.2425 - acc: 0.8981 - val_loss: 0.7516 - val_acc: 0.6431 - 15s/epoch - 351ms/step
# Learning rate is 0.1000.
# Epoch 29/200
#
# Epoch 29: val_acc did not improve from 0.66040
# 44/44 - 15s - loss: 0.2411 - acc: 0.8988 - val_loss: 0.7478 - val_acc: 0.6561 - 15s/epoch - 346ms/step
# Learning rate is 0.1000.
# Epoch 30/200
#
# Epoch 30: val_acc improved from 0.66040 to 0.66402, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_30_val_acc0.66.h5
# 44/44 - 16s - loss: 0.2439 - acc: 0.8923 - val_loss: 0.7502 - val_acc: 0.6640 - 16s/epoch - 354ms/step
# Learning rate is 0.1000.
# Epoch 31/200
#
# Epoch 31: val_acc improved from 0.66402 to 0.69220, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_31_val_acc0.69.h5
# 44/44 - 15s - loss: 0.2396 - acc: 0.8936 - val_loss: 0.6911 - val_acc: 0.6922 - 15s/epoch - 346ms/step
# Learning rate is 0.1000.
# Epoch 32/200
#
# Epoch 32: val_acc did not improve from 0.69220
# 44/44 - 15s - loss: 0.2369 - acc: 0.9028 - val_loss: 0.6774 - val_acc: 0.6900 - 15s/epoch - 346ms/step
# Learning rate is 0.1000.
# Epoch 33/200
#
# Epoch 33: val_acc did not improve from 0.69220
# 44/44 - 15s - loss: 0.2376 - acc: 0.8981 - val_loss: 0.7188 - val_acc: 0.6720 - 15s/epoch - 350ms/step
# Learning rate is 0.1000.
# Epoch 34/200
#
# Epoch 34: val_acc improved from 0.69220 to 0.69292, saving model to /content/drive/MyDrive/PD/checkpoints/exp_1_pretrained_epoch_34_val_acc0.69.h5
# 44/44 - 18s - loss: 0.2324 - acc: 0.9001 - val_loss: 0.6551 - val_acc: 0.6929 - 18s/epoch - 399ms/step
# Learning rate is 0.1000.
# Epoch 35/200
#
# Epoch 35: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2337 - acc: 0.8990 - val_loss: 0.7183 - val_acc: 0.6741 - 15s/epoch - 349ms/step
# Learning rate is 0.1000.
# Epoch 36/200
#
# Epoch 36: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2358 - acc: 0.8972 - val_loss: 0.7900 - val_acc: 0.6416 - 15s/epoch - 344ms/step
# Learning rate is 0.1000.
# Epoch 37/200
#
# Epoch 37: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2348 - acc: 0.9014 - val_loss: 0.8029 - val_acc: 0.6366 - 15s/epoch - 347ms/step
# Learning rate is 0.1000.
# Epoch 38/200
#
# Epoch 38: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2306 - acc: 0.9064 - val_loss: 0.8027 - val_acc: 0.6301 - 15s/epoch - 347ms/step
# Learning rate is 0.1000.
# Epoch 39/200
#
# Epoch 39: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2337 - acc: 0.9030 - val_loss: 0.8057 - val_acc: 0.6416 - 15s/epoch - 347ms/step
# Learning rate is 0.1000.
# Epoch 40/200
#
# Epoch 40: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2338 - acc: 0.9016 - val_loss: 0.7388 - val_acc: 0.6647 - 15s/epoch - 346ms/step
# Learning rate is 0.0500.
# Epoch 41/200
#
# Epoch 41: val_acc did not improve from 0.69292
# 44/44 - 16s - loss: 0.2168 - acc: 0.9106 - val_loss: 0.7560 - val_acc: 0.6669 - 16s/epoch - 354ms/step
# Learning rate is 0.0500.
# Epoch 42/200
#
# Epoch 42: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2130 - acc: 0.9128 - val_loss: 0.7334 - val_acc: 0.6655 - 15s/epoch - 350ms/step
# Learning rate is 0.0500.
# Epoch 43/200
#
# Epoch 43: val_acc did not improve from 0.69292
# 44/44 - 15s - loss: 0.2121 - acc: 0.9151 - val_loss: 0.7175 - val_acc: 0.6727 - 15s/epoch - 349ms/step
# Learning rate is 0.0500.
# Epoch 44/200
#
# Epoch 44: val_acc did not improve from 0.69292
# Restoring model weights from the end of the best epoch: 34.
# 44/44 - 15s - loss: 0.2098 - acc: 0.9160 - val_loss: 0.7314 - val_acc: 0.6705 - 15s/epoch - 346ms/step
# Epoch 44: early stopping

# %% [markdown]
# ## Test (SNR 100)

# %%
scores = model.evaluate([EEG_test, env_attended_test, env_unattended_test],
                        labels_test, verbose=2)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 54/54 - 1s - loss: 0.7105 - acc: 0.7291 - 604ms/epoch - 11ms/step
# Accuracy: 72.91%

# %% [markdown]
# ## Visualization

# %%
print(history.history.keys())

#plt.subplot(1,2,1)        
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')  
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('accuracy')
plt.ylabel('acc')  
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# ## Test over best epoch
#
# The information of best epoch can be seen in previous logs.

# %%
best_model=load_model(checkpoint_save_dir + 'exp_1_pretrained_epoch_34_val_acc0.69.h5')
scores = best_model.evaluate([EEG_test, env_attended_test, env_unattended_test],
                        labels_test, verbose=2)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 54/54 - 1s - loss: 0.7105 - acc: 0.7291 - 753ms/epoch - 14ms/step
# Accuracy: 72.91%

# %% [markdown]
# # Fine-Tuning (SNR 4)
#
# can be started after acquired a good model.

# %% [markdown]
# ## Dalaset Loading (SNR 4)

# %%
# load dataset
SNR_4_mat_path='/content/drive/MyDrive/PD/dataset_CNN_SNR_4.mat'
mat_path = SNR_4_mat_path
print("INFO: loading dataset SNR 4", mat_path)
mat_contents = loadmat(mat_path)
EEG_test = mat_contents['EEG_SNR_4_test_set']
env_attended_test = mat_contents['env_attended_SNR_4_test_set']
env_unattended_test = mat_contents['env_unattended_SNR_4_test_set']
EEG_train = mat_contents['EEG_SNR_4_train_set']
env_attended_train = mat_contents['env_attended_SNR_4_train_set']
env_unattended_train = mat_contents['env_unattended_SNR_4_train_set']
print("size of EEG train is", EEG_train.shape)
print("size of attended env train is", env_attended_train.shape)
print("size of unattended env train is", env_unattended_train.shape)
print("size of EEG test is", EEG_test.shape)
print("size of attended env test is", env_attended_test.shape)
print("size of unattended env test is", env_unattended_test.shape)
# Out:
# INFO: loading dataset SNR 4 /content/drive/MyDrive/PD/dataset_CNN_SNR_4.mat
# size of EEG train is (701, 3500, 64)
# size of attended env train is (701, 3500)
# size of unattended env train is (701, 3500)
# size of EEG test is (175, 3500, 64)
# size of attended env test is (175, 3500)
# size of unattended env test is (175, 3500)

# %%
# arrange this to specific window length
window_len_sec = 10; # 25,10,5,2,1 sec can be evaluated
print("INFO: resizing dataset to window length of", window_len_sec, 'seconds')
downsample_freq_CNN = 70
window_len_samples = window_len_sec * downsample_freq_CNN # 700
EEG_test.resize(EEG_test.shape[0]*int(EEG_test.shape[1]/window_len_samples), window_len_samples, EEG_test.shape[2])
env_attended_test.resize(env_attended_test.shape[0]*int(env_attended_test.shape[1]/window_len_samples), window_len_samples)
env_unattended_test.resize(env_unattended_test.shape[0]*int(env_unattended_test.shape[1]/window_len_samples), window_len_samples)
EEG_train.resize(EEG_train.shape[0]*int(EEG_train.shape[1]/window_len_samples), window_len_samples, EEG_train.shape[2])
env_attended_train.resize(env_attended_train.shape[0]*int(env_attended_train.shape[1]/window_len_samples), window_len_samples)
env_unattended_train.resize(env_unattended_train.shape[0]*int(env_unattended_train.shape[1]/window_len_samples), window_len_samples)
print("size of EEG train is ", EEG_train.shape)
print("size of attended env train is ", env_attended_train.shape)
print("size of unattended env train is ", env_unattended_train.shape)
print("size of EEG test is ", EEG_test.shape)
print("size of attended env test is ", env_attended_test.shape)
print("size of unattended env test is ", env_unattended_test.shape)
# Out:
# INFO: resizing dataset to window length of 10 seconds
# size of EEG train is  (3505, 700, 64)
# size of attended env train is  (3505, 700)
# size of unattended env train is  (3505, 700)
# size of EEG test is  (875, 700, 64)
# size of attended env test is  (875, 700)
# size of unattended env test is  (875, 700)

# %%
# equalize or balance the dataset
def batch_equalizer(eeg, env1, env2, labels):
    # present each of the eeg segments twice, where the envelopes, and thus the labels 
    # are swapped around. EEG presented in small segments [bs, window_length, 64]
    return np.concatenate([eeg,eeg], axis=0), np.concatenate([env1, env2], axis=0),np.concatenate([env2, env1], axis=0), np.concatenate([labels, (labels+1)%2], axis=0)
print("INFO: balancing dataset")
labels_test = np.zeros((EEG_test.shape[0],1))
EEG_test, env_attended_test, env_unattended_test, labels_test = batch_equalizer(EEG_test, env_attended_test, env_unattended_test, labels_test)
labels_train = np.zeros((EEG_train.shape[0],1))
EEG_train, env_attended_train, env_unattended_train, labels_train = batch_equalizer(EEG_train, env_attended_train, env_unattended_train, labels_train)
print("size of EEG train is ", EEG_train.shape)
print("size of attended env train is ", env_attended_train.shape)
print("size of unattended env train is ", env_unattended_train.shape)
print("size of EEG test is ", EEG_test.shape)
print("size of attended env test is ", env_attended_test.shape)
print("size of unattended env test is ", env_unattended_test.shape)
# Out:
# INFO: balancing dataset
# size of EEG train is  (7010, 700, 64)
# size of attended env train is  (7010, 700)
# size of unattended env train is  (7010, 700)
# size of EEG test is  (1750, 700, 64)
# size of attended env test is  (1750, 700)
# size of unattended env test is  (1750, 700)

# %%
# normalize the dataset. be careful not to useall the ram up!!! or it will crash!!!
# I can do a better normalization, but it requires RAM size. 

all_EEG = np.concatenate((EEG_train, EEG_test), axis=0)
all_env = np.concatenate((env_attended_train, env_unattended_train, env_attended_test, env_unattended_test), axis=0)
print("INFO: before normalization")
print("size of all_EEG: ", all_EEG.shape)
print("size of all_env: ", all_env.shape)
print("mean of all_EEG: ", np.mean(all_EEG), ". std of all_EEG: ", np.std(all_EEG))
print("mean of all_env: ", np.mean(all_env), ". std of all_env: ", np.std(all_env))
print("mean of EEG_train: ", np.mean(EEG_train), ". std of EEG_train: ", np.std(EEG_train))
print("mean of env_attended_train: ", np.mean(env_attended_train), ". std of EEG_train: ", np.std(env_attended_train))
print("mean of env_unattended_train: ", np.mean(env_unattended_train), ". std of EEG_train: ", np.std(env_unattended_train))
print("mean of EEG_test: ", np.mean(EEG_test), ". std of EEG_train: ", np.std(EEG_test))
print("mean of env_attended_test: ", np.mean(env_attended_test), ". std of EEG_train: ", np.std(env_attended_test))
print("mean of env_unattended_test: ", np.mean(env_unattended_test), ". std of EEG_train: ", np.std(env_unattended_test))
EEG_train = EEG_train / np.std(all_EEG)
EEG_test = EEG_test / np.std(all_EEG)
env_attended_train = env_attended_train / np.std(all_env)
env_unattended_train = env_unattended_train / np.std(all_env)
env_attended_test = env_attended_test / np.std(all_env)
env_unattended_test = env_unattended_test / np.std(all_env)
print("INFO: after normalization")
print("mean of EEG_train: ", np.mean(EEG_train), ". std of EEG_train: ", np.std(EEG_train))
print("mean of env_attended_train: ", np.mean(env_attended_train), ". std of EEG_train: ", np.std(env_attended_train))
print("mean of env_unattended_train: ", np.mean(env_unattended_train), ". std of EEG_train: ", np.std(env_unattended_train))
print("mean of EEG_test: ", np.mean(EEG_test), ". std of EEG_train: ", np.std(EEG_test))
print("mean of env_attended_test: ", np.mean(env_attended_test), ". std of EEG_train: ", np.std(env_attended_test))
print("mean of env_unattended_test: ", np.mean(env_unattended_test), ". std of EEG_train: ", np.std(env_unattended_test))
# Out:
# INFO: before normalization
# size of all_EEG:  (8760, 700, 64)
# size of all_env:  (17520, 700)
# mean of all_EEG:  -9.563519689296737e-12 . std of all_EEG:  11.662852220826007
# mean of all_env:  0.0007785422569662596 . std of all_env:  0.24805688666627107
# mean of EEG_train:  -3.7722206234015986e-10 . std of EEG_train:  11.665000954945544
# mean of env_attended_train:  0.0007850060142212136 . std of EEG_train:  0.24802928427094356
# mean of env_unattended_train:  0.0007850060142212131 . std of EEG_train:  0.24802928427094362
# mean of EEG_test:  1.4631715648142883e-09 . std of EEG_train:  11.654241033976168
# mean of env_attended_test:  0.000752650292190699 . std of EEG_train:  0.24816742150794707
# mean of env_unattended_test:  0.0007526502921906989 . std of EEG_train:  0.24816742150794716
# INFO: after normalization
# mean of EEG_train:  -3.2343894851765015e-11 . std of EEG_train:  1.000184237447143
# mean of env_attended_train:  0.003164620925349831 . std of EEG_train:  0.9998887255431667
# mean of env_unattended_train:  0.003164620925349833 . std of EEG_train:  0.9998887255431679
# mean of EEG_test:  1.2545572377960081e-10 . std of EEG_train:  0.9992616568668793
# mean of env_attended_test:  0.0030341842240537912 . std of EEG_train:  1.000445602793624
# mean of env_unattended_test:  0.003034184224053794 . std of EEG_train:  1.0004456027936235

# %% [markdown]
# ## Load the best model (ATTENTION)

# %%
best_model=load_model(checkpoint_save_dir + 'exp_1_pretrained_epoch_34_val_acc0.69.h5')

# %% [markdown]
# ## Train (SNR 4)

# %%
history = best_model.fit([EEG_train, env_attended_train, env_unattended_train], 
                    labels_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.2,
                    verbose=2,
                    shuffle=True,
                    callbacks=callbacks_list_fine_tune)
filepath = model_save_dir + "finetune_for_low_SNR.h5"
best_model.save(filepath)
# Out:
# Learning rate is 0.2000.
# Epoch 1/200
#
# Epoch 1: val_acc did not improve from 0.70899
# 44/44 - 25s - loss: 1.0438 - acc: 0.6027 - val_loss: 1.1312 - val_acc: 0.4886 - 25s/epoch - 559ms/step
# Learning rate is 0.2000.
# Epoch 2/200
#
# Epoch 2: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.6559 - acc: 0.6644 - val_loss: 1.1250 - val_acc: 0.3566 - 18s/epoch - 417ms/step
# Learning rate is 0.2000.
# Epoch 3/200
#
# Epoch 3: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.5890 - acc: 0.6858 - val_loss: 0.9105 - val_acc: 0.4137 - 19s/epoch - 421ms/step
# Learning rate is 0.2000.
# Epoch 4/200
#
# Epoch 4: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.5724 - acc: 0.6995 - val_loss: 1.0207 - val_acc: 0.3381 - 19s/epoch - 428ms/step
# Learning rate is 0.2000.
# Epoch 5/200
#
# Epoch 5: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.5570 - acc: 0.7122 - val_loss: 0.8477 - val_acc: 0.4629 - 19s/epoch - 421ms/step
# Learning rate is 0.2000.
# Epoch 6/200
#
# Epoch 6: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.5446 - acc: 0.7263 - val_loss: 0.9091 - val_acc: 0.4294 - 18s/epoch - 418ms/step
# Learning rate is 0.2000.
# Epoch 7/200
#
# Epoch 7: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.5293 - acc: 0.7370 - val_loss: 0.8329 - val_acc: 0.5050 - 18s/epoch - 419ms/step
# Learning rate is 0.2000.
# Epoch 8/200
#
# Epoch 8: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.5143 - acc: 0.7450 - val_loss: 0.8399 - val_acc: 0.5050 - 19s/epoch - 428ms/step
# Learning rate is 0.2000.
# Epoch 9/200
#
# Epoch 9: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4959 - acc: 0.7611 - val_loss: 1.0120 - val_acc: 0.4080 - 18s/epoch - 417ms/step
# Learning rate is 0.2000.
# Epoch 10/200
#
# Epoch 10: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4826 - acc: 0.7696 - val_loss: 0.9883 - val_acc: 0.4465 - 18s/epoch - 416ms/step
# Learning rate is 0.2000.
# Epoch 11/200
#
# Epoch 11: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4661 - acc: 0.7728 - val_loss: 0.9043 - val_acc: 0.4993 - 18s/epoch - 414ms/step
# Learning rate is 0.2000.
# Epoch 12/200
#
# Epoch 12: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4534 - acc: 0.7808 - val_loss: 0.8304 - val_acc: 0.5499 - 18s/epoch - 416ms/step
# Learning rate is 0.2000.
# Epoch 13/200
#
# Epoch 13: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4399 - acc: 0.7974 - val_loss: 0.9903 - val_acc: 0.4829 - 18s/epoch - 417ms/step
# Learning rate is 0.2000.
# Epoch 14/200
#
# Epoch 14: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4280 - acc: 0.8019 - val_loss: 0.7909 - val_acc: 0.5835 - 18s/epoch - 414ms/step
# Learning rate is 0.2000.
# Epoch 15/200
#
# Epoch 15: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4173 - acc: 0.8072 - val_loss: 0.9894 - val_acc: 0.4922 - 18s/epoch - 417ms/step
# Learning rate is 0.2000.
# Epoch 16/200
#
# Epoch 16: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.4044 - acc: 0.8137 - val_loss: 0.8990 - val_acc: 0.5449 - 18s/epoch - 416ms/step
# Learning rate is 0.2000.
# Epoch 17/200
#
# Epoch 17: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.3964 - acc: 0.8178 - val_loss: 0.8306 - val_acc: 0.5799 - 19s/epoch - 432ms/step
# Learning rate is 0.2000.
# Epoch 18/200
#
# Epoch 18: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3866 - acc: 0.8242 - val_loss: 0.9155 - val_acc: 0.5514 - 18s/epoch - 419ms/step
# Learning rate is 0.2000.
# Epoch 19/200
#
# Epoch 19: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3766 - acc: 0.8318 - val_loss: 0.8156 - val_acc: 0.5984 - 18s/epoch - 414ms/step
# Learning rate is 0.2000.
# Epoch 20/200
#
# Epoch 20: val_acc did not improve from 0.70899
# 44/44 - 22s - loss: 0.3681 - acc: 0.8367 - val_loss: 0.7677 - val_acc: 0.6170 - 22s/epoch - 489ms/step
# Learning rate is 0.1000.
# Epoch 21/200
#
# Epoch 21: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3490 - acc: 0.8493 - val_loss: 0.8616 - val_acc: 0.5820 - 18s/epoch - 416ms/step
# Learning rate is 0.1000.
# Epoch 22/200
#
# Epoch 22: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3424 - acc: 0.8491 - val_loss: 0.7836 - val_acc: 0.6191 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 23/200
#
# Epoch 23: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3411 - acc: 0.8499 - val_loss: 0.8229 - val_acc: 0.5956 - 18s/epoch - 417ms/step
# Learning rate is 0.1000.
# Epoch 24/200
#
# Epoch 24: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.3369 - acc: 0.8499 - val_loss: 0.8361 - val_acc: 0.5892 - 19s/epoch - 421ms/step
# Learning rate is 0.1000.
# Epoch 25/200
#
# Epoch 25: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3309 - acc: 0.8550 - val_loss: 0.8496 - val_acc: 0.5870 - 18s/epoch - 420ms/step
# Learning rate is 0.1000.
# Epoch 26/200
#
# Epoch 26: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3280 - acc: 0.8570 - val_loss: 0.7579 - val_acc: 0.6327 - 18s/epoch - 420ms/step
# Learning rate is 0.1000.
# Epoch 27/200
#
# Epoch 27: val_acc did not improve from 0.70899
# 44/44 - 21s - loss: 0.3247 - acc: 0.8595 - val_loss: 0.8378 - val_acc: 0.6020 - 21s/epoch - 471ms/step
# Learning rate is 0.1000.
# Epoch 28/200
#
# Epoch 28: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.3194 - acc: 0.8631 - val_loss: 0.8252 - val_acc: 0.6020 - 19s/epoch - 421ms/step
# Learning rate is 0.1000.
# Epoch 29/200
#
# Epoch 29: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3159 - acc: 0.8607 - val_loss: 0.8640 - val_acc: 0.5863 - 18s/epoch - 417ms/step
# Learning rate is 0.1000.
# Epoch 30/200
#
# Epoch 30: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3136 - acc: 0.8629 - val_loss: 0.8761 - val_acc: 0.5813 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 31/200
#
# Epoch 31: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3079 - acc: 0.8679 - val_loss: 0.8468 - val_acc: 0.6041 - 18s/epoch - 418ms/step
# Learning rate is 0.1000.
# Epoch 32/200
#
# Epoch 32: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3055 - acc: 0.8691 - val_loss: 0.7628 - val_acc: 0.6377 - 18s/epoch - 412ms/step
# Learning rate is 0.1000.
# Epoch 33/200
#
# Epoch 33: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3031 - acc: 0.8729 - val_loss: 0.8444 - val_acc: 0.5970 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 34/200
#
# Epoch 34: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.3014 - acc: 0.8730 - val_loss: 0.7427 - val_acc: 0.6384 - 18s/epoch - 416ms/step
# Learning rate is 0.1000.
# Epoch 35/200
#
# Epoch 35: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2965 - acc: 0.8736 - val_loss: 0.8204 - val_acc: 0.6148 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 36/200
#
# Epoch 36: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2946 - acc: 0.8729 - val_loss: 0.8121 - val_acc: 0.6084 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 37/200
#
# Epoch 37: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2912 - acc: 0.8775 - val_loss: 0.7888 - val_acc: 0.6248 - 18s/epoch - 415ms/step
# Learning rate is 0.1000.
# Epoch 38/200
#
# Epoch 38: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2877 - acc: 0.8791 - val_loss: 0.7925 - val_acc: 0.6255 - 18s/epoch - 417ms/step
# Learning rate is 0.1000.
# Epoch 39/200
#
# Epoch 39: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2872 - acc: 0.8738 - val_loss: 0.7938 - val_acc: 0.6277 - 18s/epoch - 418ms/step
# Learning rate is 0.1000.
# Epoch 40/200
#
# Epoch 40: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2854 - acc: 0.8730 - val_loss: 0.8539 - val_acc: 0.5949 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 41/200
#
# Epoch 41: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2715 - acc: 0.8861 - val_loss: 0.7998 - val_acc: 0.6191 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 42/200
#
# Epoch 42: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2673 - acc: 0.8848 - val_loss: 0.7870 - val_acc: 0.6262 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 43/200
#
# Epoch 43: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2672 - acc: 0.8896 - val_loss: 0.7452 - val_acc: 0.6427 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 44/200
#
# Epoch 44: val_acc did not improve from 0.70899
# 44/44 - 23s - loss: 0.2655 - acc: 0.8889 - val_loss: 0.7557 - val_acc: 0.6505 - 23s/epoch - 530ms/step
# Learning rate is 0.0500.
# Epoch 45/200
#
# Epoch 45: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2651 - acc: 0.8869 - val_loss: 0.7774 - val_acc: 0.6334 - 18s/epoch - 417ms/step
# Learning rate is 0.0500.
# Epoch 46/200
#
# Epoch 46: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2639 - acc: 0.8873 - val_loss: 0.7768 - val_acc: 0.6377 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 47/200
#
# Epoch 47: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2619 - acc: 0.8909 - val_loss: 0.7637 - val_acc: 0.6384 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 48/200
#
# Epoch 48: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2602 - acc: 0.8889 - val_loss: 0.7551 - val_acc: 0.6462 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 49/200
#
# Epoch 49: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2614 - acc: 0.8914 - val_loss: 0.7771 - val_acc: 0.6320 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 50/200
#
# Epoch 50: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2590 - acc: 0.8898 - val_loss: 0.7091 - val_acc: 0.6612 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 51/200
#
# Epoch 51: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2581 - acc: 0.8918 - val_loss: 0.7906 - val_acc: 0.6291 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 52/200
#
# Epoch 52: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2556 - acc: 0.8921 - val_loss: 0.7607 - val_acc: 0.6434 - 18s/epoch - 413ms/step
# Learning rate is 0.0500.
# Epoch 53/200
#
# Epoch 53: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2536 - acc: 0.8943 - val_loss: 0.7589 - val_acc: 0.6441 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 54/200
#
# Epoch 54: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2535 - acc: 0.8935 - val_loss: 0.7930 - val_acc: 0.6277 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 55/200
#
# Epoch 55: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2524 - acc: 0.8902 - val_loss: 0.7874 - val_acc: 0.6334 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 56/200
#
# Epoch 56: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2512 - acc: 0.8957 - val_loss: 0.7305 - val_acc: 0.6633 - 18s/epoch - 420ms/step
# Learning rate is 0.0500.
# Epoch 57/200
#
# Epoch 57: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2508 - acc: 0.8968 - val_loss: 0.7383 - val_acc: 0.6534 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 58/200
#
# Epoch 58: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2499 - acc: 0.8962 - val_loss: 0.7429 - val_acc: 0.6555 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 59/200
#
# Epoch 59: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2463 - acc: 0.8989 - val_loss: 0.7599 - val_acc: 0.6491 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 60/200
#
# Epoch 60: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2472 - acc: 0.8993 - val_loss: 0.7526 - val_acc: 0.6662 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 61/200
#
# Epoch 61: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2470 - acc: 0.8962 - val_loss: 0.7262 - val_acc: 0.6641 - 18s/epoch - 416ms/step
# Learning rate is 0.0500.
# Epoch 62/200
#
# Epoch 62: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2444 - acc: 0.8973 - val_loss: 0.7698 - val_acc: 0.6519 - 18s/epoch - 420ms/step
# Learning rate is 0.0500.
# Epoch 63/200
#
# Epoch 63: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2454 - acc: 0.8996 - val_loss: 0.7691 - val_acc: 0.6505 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 64/200
#
# Epoch 64: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2412 - acc: 0.9010 - val_loss: 0.7410 - val_acc: 0.6698 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 65/200
#
# Epoch 65: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2415 - acc: 0.8991 - val_loss: 0.7588 - val_acc: 0.6498 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 66/200
#
# Epoch 66: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2402 - acc: 0.8993 - val_loss: 0.7151 - val_acc: 0.6776 - 18s/epoch - 413ms/step
# Learning rate is 0.0500.
# Epoch 67/200
#
# Epoch 67: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2403 - acc: 0.9023 - val_loss: 0.7490 - val_acc: 0.6555 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 68/200
#
# Epoch 68: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2382 - acc: 0.9012 - val_loss: 0.7282 - val_acc: 0.6719 - 18s/epoch - 419ms/step
# Learning rate is 0.0500.
# Epoch 69/200
#
# Epoch 69: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2378 - acc: 0.9034 - val_loss: 0.7434 - val_acc: 0.6669 - 18s/epoch - 419ms/step
# Learning rate is 0.0500.
# Epoch 70/200
#
# Epoch 70: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2357 - acc: 0.9035 - val_loss: 0.7525 - val_acc: 0.6598 - 18s/epoch - 419ms/step
# Learning rate is 0.0500.
# Epoch 71/200
#
# Epoch 71: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2358 - acc: 0.9012 - val_loss: 0.6751 - val_acc: 0.6919 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 72/200
#
# Epoch 72: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2347 - acc: 0.9048 - val_loss: 0.6821 - val_acc: 0.6919 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 73/200
#
# Epoch 73: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2372 - acc: 0.9026 - val_loss: 0.7327 - val_acc: 0.6698 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 74/200
#
# Epoch 74: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2363 - acc: 0.9005 - val_loss: 0.7073 - val_acc: 0.6726 - 18s/epoch - 418ms/step
# Learning rate is 0.0500.
# Epoch 75/200
#
# Epoch 75: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2337 - acc: 0.9050 - val_loss: 0.7052 - val_acc: 0.6797 - 18s/epoch - 419ms/step
# Learning rate is 0.0500.
# Epoch 76/200
#
# Epoch 76: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2320 - acc: 0.9035 - val_loss: 0.7366 - val_acc: 0.6683 - 18s/epoch - 417ms/step
# Learning rate is 0.0500.
# Epoch 77/200
#
# Epoch 77: val_acc did not improve from 0.70899
# 44/44 - 19s - loss: 0.2319 - acc: 0.9058 - val_loss: 0.7048 - val_acc: 0.6812 - 19s/epoch - 421ms/step
# Learning rate is 0.0500.
# Epoch 78/200
#
# Epoch 78: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2314 - acc: 0.9050 - val_loss: 0.7447 - val_acc: 0.6669 - 18s/epoch - 415ms/step
# Learning rate is 0.0500.
# Epoch 79/200
#
# Epoch 79: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2301 - acc: 0.9066 - val_loss: 0.7685 - val_acc: 0.6626 - 18s/epoch - 414ms/step
# Learning rate is 0.0500.
# Epoch 80/200
#
# Epoch 80: val_acc did not improve from 0.70899
# 44/44 - 18s - loss: 0.2283 - acc: 0.9085 - val_loss: 0.7042 - val_acc: 0.6790 - 18s/epoch - 418ms/step
# Learning rate is 0.0200.
# Epoch 81/200
#
# Epoch 81: val_acc did not improve from 0.70899
# Restoring model weights from the end of the best epoch: 71.
# 44/44 - 18s - loss: 0.2208 - acc: 0.9155 - val_loss: 0.7195 - val_acc: 0.6755 - 18s/epoch - 417ms/step
# Epoch 81: early stopping

# %% [markdown]
# ## Test (SNR 4)

# %%
scores = best_model.evaluate([EEG_test, env_attended_test, env_unattended_test],
                        labels_test, verbose=2)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 55/55 - 1s - loss: 0.7679 - acc: 0.7269 - 775ms/epoch - 14ms/step
# Accuracy: 72.69%

# %% [markdown]
# ## Visualization

# %%
print(history.history.keys())

#plt.subplot(1,2,1)        
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')  
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('accuracy')
plt.ylabel('acc')  
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# # Test for given unknown test set

# %% [markdown]
# ## evaluate SNR 100 (`pretrained_model`)

# %%
pretrained_model = load_model(checkpoint_save_dir + 'exp_1_pretrained_epoch_34_val_acc0.69.h5')
for test_subj in test_subjs:
  for name_subject in os.listdir(test_subj):
    filename = os.fsdecode(name_subject)
    if filename == '.DS_Store':
      continue
    dir_subject = test_subj + '/' + filename
    for name_trial in os.listdir(dir_subject):
      trialname = os.fsdecode(name_trial)
      dir_trial = dir_subject + '/' + trialname
      trial = loadmat(dir_trial)
      trial = trial['trial']
      FileHeader = trial['FileHeader']
      SNR = FileHeader[0, 0]['SNR'][0][0][0][0]
      if SNR == 100:
        print('sub', filename,'\t ', end='')
        print(trialname, '\t ', end='')
        EEG = trial['ProcessedEegData'][0][0]
        track1 = trial['Processedtrack1'][0][0]
        track2 = trial['Processedtrack2'][0][0]
        EEG = EEG[0:700,:]
        track1 = track1[0:700,:]
        track2 = track2[0:700,:]
        EEG = EEG.reshape(1, 700, 64)
        track1 = track1.reshape(1, 700)
        track2 = track2.reshape(1, 700)
        score = pretrained_model.predict([EEG, track1, track2])
        score = score[0][0]
        if score<0.5:
          score = 1
        elif score <=1:
          score = 2
        else:
          print("error, score=",score)
        print(score,' ')
# Out:
# sub 025 	 trial-10.mat 	 2
# sub 025 	 trial-13.mat 	 1
# sub 025 	 trial-14.mat 	 2
# sub 025 	 trial-16.mat 	 2
# sub 025 	 trial-18.mat 	 2
# sub 025 	 trial-2.mat 	 1
# sub 025 	 trial-27.mat 	 1
# sub 003 	 trial-17.mat 	 2
# sub 003 	 trial-21.mat 	 1
# sub 003 	 trial-22.mat 	 1
# sub 003 	 trial-26.mat 	 1
# sub 003 	 trial-27.mat 	 2
# sub 003 	 trial-29.mat 	 1
# sub 003 	 trial-3.mat 	 2
# sub 003 	 trial-30.mat 	 1
# sub 003 	 trial-31.mat 	 2
# sub 003 	 trial-32.mat 	 2
# sub 003 	 trial-33.mat 	 1
# sub 003 	 trial-36.mat 	 2
# sub 003 	 trial-38.mat 	 2
# sub 003 	 trial-4.mat 	 1
# sub 003 	 trial-42.mat 	 1
# sub 003 	 trial-43.mat 	 1
# sub 003 	 trial-44.mat 	 1
# sub 003 	 trial-45.mat 	 1
# sub 003 	 trial-47.mat 	 1
# sub 003 	 trial-7.mat 	 1
# sub 003 	 trial-8.mat 	 1
# sub 003 	 trial-9.mat 	 1
# sub 016 	 trial-1.mat 	 2
# sub 016 	 trial-10.mat 	 1
# sub 016 	 trial-11.mat 	 1
# sub 016 	 trial-16.mat 	 1
# sub 016 	 trial-15.mat 	 2
# sub 016 	 trial-18.mat 	 1
# sub 016 	 trial-17.mat 	 1
# sub 016 	 trial-19.mat 	 1
# sub 016 	 trial-22.mat 	 2
# sub 016 	 trial-25.mat 	 1
# sub 016 	 trial-3.mat 	 2
# sub 016 	 trial-30.mat 	 1
# sub 016 	 trial-31.mat 	 1
# sub 016 	 trial-34.mat 	 2
# sub 016 	 trial-35.mat 	 2
# sub 016 	 trial-37.mat 	 1
# sub 016 	 trial-36.mat 	 2
# sub 016 	 trial-38.mat 	 2
# sub 016 	 trial-39.mat 	 1
# sub 016 	 trial-44.mat 	 1
# sub 016 	 trial-46.mat 	 2
# sub 016 	 trial-6.mat 	 2
# sub 016 	 trial-5.mat 	 2
# sub 016 	 trial-7.mat 	 2
# sub 029 	 trial-10.mat 	 1
# sub 029 	 trial-12.mat 	 2
# sub 029 	 trial-17.mat 	 2
# sub 029 	 trial-18.mat 	 1
# sub 029 	 trial-21.mat 	 1
# sub 029 	 trial-20.mat 	 1
# sub 029 	 trial-22.mat 	 2
# sub 029 	 trial-29.mat 	 1
# sub 029 	 trial-30.mat 	 2
# sub 029 	 trial-3.mat 	 1
# sub 029 	 trial-31.mat 	 2
# sub 029 	 trial-33.mat 	 1
# sub 029 	 trial-34.mat 	 1
# sub 029 	 trial-37.mat 	 2
# sub 029 	 trial-39.mat 	 1
# sub 029 	 trial-40.mat 	 2
# sub 029 	 trial-41.mat 	 1
# sub 029 	 trial-43.mat 	 1
# sub 029 	 trial-46.mat 	 1
# sub 029 	 trial-45.mat 	 1
# sub 029 	 trial-48.mat 	 2
# sub 029 	 trial-5.mat 	 1
# sub 029 	 trial-7.mat 	 1
# sub 029 	 trial-8.mat 	 1
# sub 028 	 trial-1.mat 	 1
# sub 028 	 trial-11.mat 	 2
# sub 028 	 trial-14.mat 	 2
# sub 028 	 trial-13.mat 	 1
# sub 028 	 trial-17.mat 	 2
# sub 028 	 trial-18.mat 	 2
# sub 028 	 trial-19.mat 	 1
# sub 034 	 trial-40.mat 	 2
# sub 034 	 trial-42.mat 	 1
# sub 034 	 trial-43.mat 	 2
# sub 034 	 trial-44.mat 	 1
# sub 034 	 trial-47.mat 	 2
# sub 034 	 trial-48.mat 	 1
# sub 034 	 trial-8.mat 	 1
# sub 034 	 trial-7.mat 	 1
# sub 042 	 trial-10.mat 	 2
# sub 042 	 trial-11.mat 	 2
# sub 042 	 trial-15.mat 	 1
# sub 042 	 trial-17.mat 	 2
# sub 042 	 trial-19.mat 	 2
# sub 042 	 trial-20.mat 	 2
# sub 042 	 trial-21.mat 	 2
# sub 042 	 trial-22.mat 	 1
# sub 042 	 trial-25.mat 	 1
# sub 042 	 trial-28.mat 	 1
# sub 042 	 trial-5.mat 	 2
# sub 042 	 trial-6.mat 	 2
# sub 042 	 trial-7.mat 	 2
# sub 042 	 trial-8.mat 	 2
# sub 042 	 trial-9.mat 	 1
# sub 040 	 trial-10.mat 	 2
# sub 040 	 trial-11.mat 	 2
# sub 040 	 trial-16.mat 	 1
# sub 040 	 trial-20.mat 	 1
# sub 040 	 trial-21.mat 	 1
# sub 040 	 trial-22.mat 	 2
# sub 040 	 trial-23.mat 	 1
# sub 040 	 trial-24.mat 	 2
# sub 040 	 trial-26.mat 	 1
# sub 040 	 trial-28.mat 	 1
# sub 040 	 trial-29.mat 	 2
# sub 040 	 trial-3.mat 	 1
# sub 040 	 trial-5.mat 	 2
# sub 040 	 trial-6.mat 	 1
# sub 040 	 trial-7.mat 	 1
# sub 040 	 trial-8.mat 	 1
# sub 040 	 trial-9.mat 	 2
# sub 041 	 trial-1.mat 	 2
# sub 041 	 trial-11.mat 	 1
# sub 041 	 trial-12.mat 	 2
# sub 041 	 trial-14.mat 	 2
# sub 041 	 trial-19.mat 	 1
# sub 041 	 trial-21.mat 	 2
# sub 041 	 trial-22.mat 	 1
# sub 041 	 trial-23.mat 	 1
# sub 041 	 trial-24.mat 	 2
# sub 041 	 trial-25.mat 	 2
# sub 041 	 trial-26.mat 	 1
# sub 041 	 trial-28.mat 	 2
# sub 041 	 trial-29.mat 	 1
# sub 041 	 trial-30.mat 	 1
# sub 041 	 trial-4.mat 	 1
# sub 041 	 trial-5.mat 	 1

# %% [markdown]
# ## evaluate SNR 4 (`finetuned_model`)

# %%
finetuned_model = load_model(filepath)
for test_subj in test_subjs:
  for name_subject in os.listdir(test_subj):
    filename = os.fsdecode(name_subject)
    if filename == '.DS_Store':
      continue
    dir_subject = test_subj + '/' + filename
    for name_trial in os.listdir(dir_subject):
      trialname = os.fsdecode(name_trial)
      dir_trial = dir_subject + '/' + trialname
      trial = loadmat(dir_trial)
      trial = trial['trial']
      FileHeader = trial['FileHeader']
      SNR = FileHeader[0, 0]['SNR'][0][0][0][0]
      if SNR == 4:
        print('sub', filename,'\t ', end='')
        print(trialname, '\t ', end='')
        EEG = trial['ProcessedEegData'][0][0]
        track1 = trial['Processedtrack1'][0][0]
        track2 = trial['Processedtrack2'][0][0]
        EEG = EEG[0:700,:]
        track1 = track1[0:700,:]
        track2 = track2[0:700,:]
        EEG = EEG.reshape(1, 700, 64)
        track1 = track1.reshape(1, 700)
        track2 = track2.reshape(1, 700)
        score = finetuned_model.predict([EEG, track1, track2])
        score = score[0][0]
        if score<0.5:
          score = 1
        elif score <=1:
          score = 2
        else:
          print("error, score=",score)
        print(score,' ')
# Out:
# sub 025 	 trial-1.mat 	 2
# sub 025 	 trial-11.mat 	 1
# sub 025 	 trial-12.mat 	 2
# sub 025 	 trial-15.mat 	 2
# sub 025 	 trial-17.mat 	 2
# sub 025 	 trial-19.mat 	 1
# sub 025 	 trial-20.mat 	 2
# sub 025 	 trial-21.mat 	 1
# sub 025 	 trial-22.mat 	 1
# sub 025 	 trial-24.mat 	 2
# sub 025 	 trial-23.mat 	 2
# sub 025 	 trial-25.mat 	 1
# sub 025 	 trial-29.mat 	 2
# sub 025 	 trial-28.mat 	 1
# sub 025 	 trial-3.mat 	 1
# sub 025 	 trial-32.mat 	 2
# sub 025 	 trial-34.mat 	 1
# sub 025 	 trial-35.mat 	 1
# sub 025 	 trial-4.mat 	 1
# sub 025 	 trial-40.mat 	 2
# sub 025 	 trial-41.mat 	 2
# sub 025 	 trial-44.mat 	 1
# sub 025 	 trial-7.mat 	 2
# sub 025 	 trial-9.mat 	 2
# sub 023 	 trial-12.mat 	 2
# sub 023 	 trial-13.mat 	 2
# sub 023 	 trial-15.mat 	 2
# sub 023 	 trial-14.mat 	 2
# sub 023 	 trial-16.mat 	 2
# sub 023 	 trial-18.mat 	 1
# sub 023 	 trial-19.mat 	 1
# sub 023 	 trial-2.mat 	 1
# sub 023 	 trial-20.mat 	 2
# sub 023 	 trial-22.mat 	 1
# sub 023 	 trial-21.mat 	 2
# sub 023 	 trial-23.mat 	 2
# sub 023 	 trial-24.mat 	 1
# sub 023 	 trial-26.mat 	 2
# sub 023 	 trial-27.mat 	 2
# sub 023 	 trial-29.mat 	 1
# sub 023 	 trial-3.mat 	 2
# sub 023 	 trial-31.mat 	 1
# sub 023 	 trial-30.mat 	 1
# sub 023 	 trial-34.mat 	 1
# sub 023 	 trial-5.mat 	 1
# sub 023 	 trial-4.mat 	 1
# sub 023 	 trial-7.mat 	 1
# sub 023 	 trial-9.mat 	 2
# sub 007 	 trial-10.mat 	 1
# sub 007 	 trial-13.mat 	 2
# sub 007 	 trial-14.mat 	 1
# sub 007 	 trial-17.mat 	 2
# sub 007 	 trial-18.mat 	 2
# sub 007 	 trial-2.mat 	 2
# sub 007 	 trial-21.mat 	 1
# sub 007 	 trial-25.mat 	 2
# sub 007 	 trial-30.mat 	 2
# sub 007 	 trial-31.mat 	 1
# sub 007 	 trial-32.mat 	 1
# sub 007 	 trial-34.mat 	 2
# sub 007 	 trial-35.mat 	 1
# sub 007 	 trial-37.mat 	 1
# sub 007 	 trial-4.mat 	 2
# sub 007 	 trial-40.mat 	 2
# sub 007 	 trial-41.mat 	 2
# sub 007 	 trial-42.mat 	 2
# sub 007 	 trial-44.mat 	 1
# sub 007 	 trial-46.mat 	 1
# sub 007 	 trial-47.mat 	 1
# sub 005 	 trial-34.mat 	 1
# sub 005 	 trial-36.mat 	 1
# sub 005 	 trial-37.mat 	 1
# sub 005 	 trial-39.mat 	 2
# sub 005 	 trial-4.mat 	 1
# sub 005 	 trial-40.mat 	 2
# sub 005 	 trial-44.mat 	 2
# sub 005 	 trial-6.mat 	 2
# sub 005 	 trial-7.mat 	 2
# sub 005 	 trial-8.mat 	 1
# sub 005 	 trial-9.mat 	 2
# sub 034 	 trial-1.mat 	 2
# sub 034 	 trial-13.mat 	 1
# sub 034 	 trial-18.mat 	 1
# sub 034 	 trial-19.mat 	 1
# sub 034 	 trial-2.mat 	 1
# sub 034 	 trial-20.mat 	 1
# sub 034 	 trial-21.mat 	 2
# sub 034 	 trial-24.mat 	 2
# sub 034 	 trial-23.mat 	 2
# sub 034 	 trial-26.mat 	 2
# sub 034 	 trial-27.mat 	 1
# sub 034 	 trial-28.mat 	 2
# sub 034 	 trial-29.mat 	 1
# sub 034 	 trial-33.mat 	 1
# sub 034 	 trial-36.mat 	 2
# sub 034 	 trial-38.mat 	 2
# sub 034 	 trial-39.mat 	 2
# sub 034 	 trial-4.mat 	 2
# sub 034 	 trial-41.mat 	 2
# sub 034 	 trial-45.mat 	 1
# sub 034 	 trial-46.mat 	 1
# sub 034 	 trial-5.mat 	 1
# sub 034 	 trial-6.mat 	 1
# sub 034 	 trial-9.mat 	 2
# sub 042 	 trial-1.mat 	 2
# sub 042 	 trial-12.mat 	 2
# sub 042 	 trial-13.mat 	 1
# sub 042 	 trial-14.mat 	 1
# sub 042 	 trial-16.mat 	 1
# sub 042 	 trial-18.mat 	 1
# sub 042 	 trial-2.mat 	 2
# sub 042 	 trial-23.mat 	 2
# sub 042 	 trial-24.mat 	 1
# sub 042 	 trial-26.mat 	 1
# sub 042 	 trial-27.mat 	 1
# sub 042 	 trial-29.mat 	 2
# sub 042 	 trial-3.mat 	 2
# sub 042 	 trial-30.mat 	 2
# sub 042 	 trial-4.mat 	 1
# sub 040 	 trial-1.mat 	 2
# sub 040 	 trial-12.mat 	 2
# sub 040 	 trial-13.mat 	 1
# sub 040 	 trial-14.mat 	 1
# sub 040 	 trial-15.mat 	 2
# sub 040 	 trial-17.mat 	 2
# sub 040 	 trial-18.mat 	 1
# sub 040 	 trial-19.mat 	 1
# sub 040 	 trial-2.mat 	 1
# sub 040 	 trial-25.mat 	 2
# sub 040 	 trial-27.mat 	 1
# sub 040 	 trial-30.mat 	 1
# sub 040 	 trial-4.mat 	 1
# sub 041 	 trial-10.mat 	 2
# sub 041 	 trial-13.mat 	 2
# sub 041 	 trial-15.mat 	 1
# sub 041 	 trial-16.mat 	 2
# sub 041 	 trial-17.mat 	 1
# sub 041 	 trial-18.mat 	 1
# sub 041 	 trial-2.mat 	 2
# sub 041 	 trial-20.mat 	 2
# sub 041 	 trial-27.mat 	 2
# sub 041 	 trial-3.mat 	 1
# sub 041 	 trial-6.mat 	 1
# sub 041 	 trial-7.mat 	 2
# sub 041 	 trial-8.mat 	 1
# sub 041 	 trial-9.mat 	 1
